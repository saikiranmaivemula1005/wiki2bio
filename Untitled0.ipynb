# %%
print(pwd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-87c058283866> in <module>()
# ----> 1 print(pwd)
#
# NameError: name 'pwd' is not defined
